# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("/home/harwick/Downloads/Data/car_data/train-data.csv")
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats        Price
# count  6019.000000  6019.000000       6.019000e+03  5977.000000  6019.000000
# mean   3009.000000  2013.358199       5.873838e+04     5.278735     9.479468
# std    1737.679967     3.269742       9.126884e+04     0.808840    11.187917
# min       0.000000  1998.000000       1.710000e+02     0.000000     0.440000
# 25%    1504.500000  2011.000000       3.400000e+04     5.000000     3.500000
# 50%    3009.000000  2014.000000       5.300000e+04     5.000000     5.640000
# 75%    4513.500000  2016.000000       7.300000e+04     5.000000     9.950000
# max    6018.000000  2019.000000       6.500000e+06    10.000000   160.000000

# %%
df.shape
# Out:
# (6019, 14)

# %%
df['Name'].value_counts()
# Out:
# Mahindra XUV500 W8 2WD           49
# Maruti Swift VDI                 45
# Honda City 1.5 S MT              34
# Maruti Swift Dzire VDI           34
# Maruti Swift VDI BSIV            31
#                                  ..
# Ford Fiesta Titanium 1.5 TDCi     1
# Mahindra Scorpio S10 AT 4WD       1
# Hyundai i20 1.2 Era               1
# Toyota Camry W4 (AT)              1
# Mahindra Xylo D4 BSIV             1
# Name: Name, Length: 1878, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power',
#        'Seats', 'New_Price', 'Price'],
#       dtype='object')

# %%
df['Location'].value_counts()
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %%
df['Fuel_Type'].value_counts()
# Out:
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
print(df.isna().sum())
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
#Encoding
#get_dummies
dummy=pd.get_dummies(df[['Location','Fuel_Type','Transmission','Owner_Type']],drop_first=True)

# %%
#concatenation - joining
dfe=pd.concat([df,dummy],axis=1)
dfe
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
dfe=dfe.drop(['Name','Location','Transmission','Fuel_Type','Owner_Type','New_Price'],axis=1)
dfe
# Out:
#       Unnamed: 0  Year  Kilometers_Driven     Mileage   Engine      Power  \
# 0              0  2010              72000  26.6 km/kg   998 CC  58.16 bhp
# 1              1  2015              41000  19.67 kmpl  1582 CC  126.2 bhp
# 2              2  2011              46000   18.2 kmpl  1199 CC   88.7 bhp
# 3              3  2012              87000  20.77 kmpl  1248 CC  88.76 bhp
# 4              4  2013              40670   15.2 kmpl  1968 CC  140.8 bhp
# ...          ...   ...                ...         ...      ...        ...
# 6014        6014  2014              27365   28.4 kmpl  1248 CC     74 bhp
# 6015        6015  2015             100000   24.4 kmpl  1120 CC     71 bhp
# 6016        6016  2012              55000   14.0 kmpl  2498 CC    112 bhp
# 6017        6017  2013              46000   18.9 kmpl   998 CC   67.1 bhp
# 6018        6018  2011              47000  25.44 kmpl   936 CC   57.6 bhp
#
#       Seats  Price  Location_Bangalore  Location_Chennai  ...  \
# ...

# %%
#Remove symbols or data 
dfe['Mileage']=dfe['Mileage'].str.replace('kmpl','')
dfe
# Out:
#       Unnamed: 0  Year  Kilometers_Driven     Mileage   Engine      Power  \
# 0              0  2010              72000  26.6 km/kg   998 CC  58.16 bhp
# 1              1  2015              41000      19.67   1582 CC  126.2 bhp
# 2              2  2011              46000       18.2   1199 CC   88.7 bhp
# 3              3  2012              87000      20.77   1248 CC  88.76 bhp
# 4              4  2013              40670       15.2   1968 CC  140.8 bhp
# ...          ...   ...                ...         ...      ...        ...
# 6014        6014  2014              27365       28.4   1248 CC     74 bhp
# 6015        6015  2015             100000       24.4   1120 CC     71 bhp
# 6016        6016  2012              55000       14.0   2498 CC    112 bhp
# 6017        6017  2013              46000       18.9    998 CC   67.1 bhp
# 6018        6018  2011              47000      25.44    936 CC   57.6 bhp
#
#       Seats  Price  Location_Bangalore  Location_Chennai  ...  \
# ...

# %%
dfe['Mileage']=dfe['Mileage'].str.replace('km/kg','')
dfe
# Out:
#       Unnamed: 0  Year  Kilometers_Driven Mileage   Engine      Power  Seats  \
# 0              0  2010              72000   26.6    998 CC  58.16 bhp    5.0
# 1              1  2015              41000  19.67   1582 CC  126.2 bhp    5.0
# 2              2  2011              46000   18.2   1199 CC   88.7 bhp    5.0
# 3              3  2012              87000  20.77   1248 CC  88.76 bhp    7.0
# 4              4  2013              40670   15.2   1968 CC  140.8 bhp    5.0
# ...          ...   ...                ...     ...      ...        ...    ...
# 6014        6014  2014              27365   28.4   1248 CC     74 bhp    5.0
# 6015        6015  2015             100000   24.4   1120 CC     71 bhp    5.0
# 6016        6016  2012              55000   14.0   2498 CC    112 bhp    8.0
# 6017        6017  2013              46000   18.9    998 CC   67.1 bhp    5.0
# 6018        6018  2011              47000  25.44    936 CC   57.6 bhp    5.0
#
# ...

# %%
dfe['Engine']=dfe['Engine'].str.replace('CC','')
dfe['Power']=dfe['Power'].str.replace('bhp','')

# %%
#Replacing missing value
dfe['Mileage']=dfe['Mileage'].str.replace('null','0')
dfe['Engine']=dfe['Engine'].str.replace('null','0')
dfe['Power']=dfe['Power'].str.replace('null','0')

# %%
dfe.dtypes
# Out:
# Unnamed: 0                     int64
# Year                           int64
# Kilometers_Driven              int64
# Mileage                       object
# Engine                        object
# Power                         object
# Seats                        float64
# Price                        float64
# Location_Bangalore             uint8
# Location_Chennai               uint8
# Location_Coimbatore            uint8
# Location_Delhi                 uint8
# Location_Hyderabad             uint8
# Location_Jaipur                uint8
# Location_Kochi                 uint8
# Location_Kolkata               uint8
# Location_Mumbai                uint8
# Location_Pune                  uint8
# Fuel_Type_Diesel               uint8
# Fuel_Type_Electric             uint8
# Fuel_Type_LPG                  uint8
# Fuel_Type_Petrol               uint8
# Transmission_Manual            uint8
# Owner_Type_Fourth & Above      uint8
# Owner_Type_Second              uint8
# ...

# %%
#have to convert object type of engine,mileage, power into int or float
dfe['Mileage']=dfe['Mileage'].astype('float')
dfe['Power']=dfe['Power'].astype('float')
dfe['Engine']=dfe['Engine'].astype('float')
dfe.dtypes
# Out:
# Unnamed: 0                     int64
# Year                           int64
# Kilometers_Driven              int64
# Mileage                      float64
# Engine                       float64
# Power                        float64
# Seats                        float64
# Price                        float64
# Location_Bangalore             uint8
# Location_Chennai               uint8
# Location_Coimbatore            uint8
# Location_Delhi                 uint8
# Location_Hyderabad             uint8
# Location_Jaipur                uint8
# Location_Kochi                 uint8
# Location_Kolkata               uint8
# Location_Mumbai                uint8
# Location_Pune                  uint8
# Fuel_Type_Diesel               uint8
# Fuel_Type_Electric             uint8
# Fuel_Type_LPG                  uint8
# Fuel_Type_Petrol               uint8
# Transmission_Manual            uint8
# Owner_Type_Fourth & Above      uint8
# Owner_Type_Second              uint8
# ...

# %%
#NaN
#now we have to change null value into nan(Not A Number)
import numpy as np
dfe.loc[dfe.Engine==0,'Engine']=np.NaN

# %%
dfe.loc[dfe.Power==0,'Power']=np.NaN
dfe.loc[dfe.Mileage==0,'Mileage']=np.NaN

# %%
dfe.isnull().sum()
# Out:
# Unnamed: 0                     0
# Year                           0
# Kilometers_Driven              0
# Mileage                       70
# Engine                        36
# Power                        143
# Seats                         42
# Price                          0
# Location_Bangalore             0
# Location_Chennai               0
# Location_Coimbatore            0
# Location_Delhi                 0
# Location_Hyderabad             0
# Location_Jaipur                0
# Location_Kochi                 0
# Location_Kolkata               0
# Location_Mumbai                0
# Location_Pune                  0
# Fuel_Type_Diesel               0
# Fuel_Type_Electric             0
# Fuel_Type_LPG                  0
# Fuel_Type_Petrol               0
# Transmission_Manual            0
# Owner_Type_Fourth & Above      0
# Owner_Type_Second              0
# Owner_Type_Third               0
# dtype: int64

# %%
#filling missing values with mean and mode
dfe['Engine']=dfe['Engine'].fillna(dfe['Engine'].mean())
dfe['Power']=dfe['Power'].fillna(dfe['Power'].mean())
dfe['Mileage']=dfe['Mileage'].fillna(dfe['Mileage'].mean())
dfe['Seats']=dfe['Seats'].fillna(dfe['Seats'].mode()[0]) #mode(index) - filling with most common element
dfe
# Out:
#       Unnamed: 0  Year  Kilometers_Driven  Mileage  Engine   Power  Seats  \
# 0              0  2010              72000    26.60   998.0   58.16    5.0
# 1              1  2015              41000    19.67  1582.0  126.20    5.0
# 2              2  2011              46000    18.20  1199.0   88.70    5.0
# 3              3  2012              87000    20.77  1248.0   88.76    7.0
# 4              4  2013              40670    15.20  1968.0  140.80    5.0
# ...          ...   ...                ...      ...     ...     ...    ...
# 6014        6014  2014              27365    28.40  1248.0   74.00    5.0
# 6015        6015  2015             100000    24.40  1120.0   71.00    5.0
# 6016        6016  2012              55000    14.00  2498.0  112.00    8.0
# 6017        6017  2013              46000    18.90   998.0   67.10    5.0
# 6018        6018  2011              47000    25.44   936.0   57.60    5.0
#
#       Price  Location_Bangalore  Location_Chennai  ...  Location_Mumbai  \
# ...

# %%
x=dfe.drop(['Price','Fuel_Type_Electric'],axis=1).values #fuel type eletric is not in test data (tfe)
y=dfe['Price'].values
y
# Out:
# array([ 1.75, 12.5 ,  4.5 , ...,  2.9 ,  2.65,  2.5 ])

# %%
# from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
# from sklearn.linear_model import LinearRegression
# reg=LinearRegression()
# reg.fit(x_train,y_train)
# y_pred1=reg.predict(x_test)
# y_pred1
# Out:
# array([40.09454025,  3.34723789, 10.05394392, ...,  3.26048785,
#         5.01071146,  1.89051743])

# %%
# from sklearn.metrics import r2_score
# print(r2_score(y_test,y_pred1))
# Out:
# 0.521534541060148

# %%
import numpy as np
import pandas as pd 
tf=pd.read_csv('/home/harwick/Downloads/Data/car_data/test-data.csv')
tf
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
print(tf.describe())
print(tf['New_Price'].count)
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats
# count  1234.000000  1234.000000        1234.000000  1223.000000
# mean    616.500000  2013.400324       58507.288493     5.284546
# std     356.369424     3.179700       35598.702098     0.825622
# min       0.000000  1996.000000        1000.000000     2.000000
# 25%     308.250000  2011.000000       34000.000000     5.000000
# 50%     616.500000  2014.000000       54572.500000     5.000000
# 75%     924.750000  2016.000000       75000.000000     5.000000
# max    1233.000000  2019.000000      350000.000000    10.000000
# <bound method Series.count of 0              NaN
# 1              NaN
# 2       25.27 Lakh
# 3              NaN
# 4              NaN
#            ...
# 1229           NaN
# 1230           NaN
# 1231           NaN
# 1232           NaN
# 1233           NaN
# Name: New_Price, Length: 1234, dtype: object>

# %%
tf.shape
tf.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power',
#        'Seats', 'New_Price'],
#       dtype='object')

# %%
tf['Name'].value_counts()
# Out:
# Maruti Alto LXi                                         9
# Honda City 1.5 V MT                                     8
# Maruti Swift Dzire VDI                                  8
# Volkswagen Polo 1.2 MPI Highline                        8
# Hyundai i10 Magna                                       7
#                                                        ..
# Hyundai Santro GLS I - Euro II                          1
# Honda City i DTec VX Option BL                          1
# Land Rover Discovery 4 SDV6 SE                          1
# Hyundai Verna CRDi 1.6 SX Option                        1
# Mercedes-Benz E-Class 2009-2013 E 220 CDI Avantgarde    1
# Name: Name, Length: 769, dtype: int64

# %%
print(tf.isna().sum())
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 10
# Power                  10
# Seats                  11
# New_Price            1052
# dtype: int64

# %%
#Encoding
#get_dummies
dummy=pd.get_dummies(tf[['Location','Fuel_Type','Transmission','Owner_Type']],drop_first=True)

# %%
#concatenation - joining
tfe=pd.concat([tf,dummy],axis=1)
tfe
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
#Remove symbols or data 
tfe['Mileage']=tfe['Mileage'].str.replace('kmpl','')
tfe
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
tfe['Mileage']=tfe['Mileage'].str.replace('km/kg','')
tfe
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
tfe['Engine']=tfe['Engine'].str.replace('CC','')
tfe['Power']=tfe['Power'].str.replace('bhp','')

# %%
#Replacing missing value
tfe['Mileage']=tfe['Mileage'].str.replace('null','0')
tfe['Engine']=tfe['Engine'].str.replace('null','0')
tfe['Power']=tfe['Power'].str.replace('null','0')

# %%
#have to convert object type of engine,mileage, power into int or float
tfe['Mileage']=tfe['Mileage'].astype('float')
tfe['Power']=tfe['Power'].astype('float')
tfe['Engine']=tfe['Engine'].astype('float')
tfe.dtypes
# Out:
# Unnamed: 0                     int64
# Name                          object
# Location                      object
# Year                           int64
# Kilometers_Driven              int64
# Fuel_Type                     object
# Transmission                  object
# Owner_Type                    object
# Mileage                      float64
# Engine                       float64
# Power                        float64
# Seats                        float64
# New_Price                     object
# Location_Bangalore             uint8
# Location_Chennai               uint8
# Location_Coimbatore            uint8
# Location_Delhi                 uint8
# Location_Hyderabad             uint8
# Location_Jaipur                uint8
# Location_Kochi                 uint8
# Location_Kolkata               uint8
# Location_Mumbai                uint8
# Location_Pune                  uint8
# Fuel_Type_Diesel               uint8
# Fuel_Type_LPG                  uint8
# ...

# %%
#NaN
#now we have to change null value into nan(Not A Number)
import numpy as np
tfe.loc[tfe.Engine==0,'Engine']=np.NaN

# %%
tfe.loc[tfe.Power==0,'Power']=np.NaN
tfe.loc[tfe.Mileage==0,'Mileage']=np.NaN

# %%
tfe=tfe.drop(['Name','Location','Transmission','Fuel_Type','Owner_Type','New_Price'],axis=1)
tfe
# Out:
#       Unnamed: 0  Year  Kilometers_Driven  Mileage  Engine   Power  Seats  \
# 0              0  2014              40929    32.26   998.0   58.20    4.0
# 1              1  2013              54493    24.70   796.0   47.30    5.0
# 2              2  2017              34000    13.68  2393.0  147.80    7.0
# 3              3  2012             139000    23.59  1364.0     NaN    5.0
# 4              4  2014              29000    18.50  1197.0   82.85    5.0
# ...          ...   ...                ...      ...     ...     ...    ...
# 1229        1229  2011              89411    20.54  1598.0  103.60    5.0
# 1230        1230  2015              59000    17.21  1197.0  103.60    5.0
# 1231        1231  2012              28000    23.08  1461.0   63.10    5.0
# 1232        1232  2013              52262    17.20  1197.0  103.60    5.0
# 1233        1233  2014              72443    10.00  2148.0  170.00    5.0
#
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  ...  \
# ...

# %%
tfe.isnull().sum()
# Out:
# Unnamed: 0                    0
# Year                          0
# Kilometers_Driven             0
# Mileage                      13
# Engine                       10
# Power                        32
# Seats                        11
# Location_Bangalore            0
# Location_Chennai              0
# Location_Coimbatore           0
# Location_Delhi                0
# Location_Hyderabad            0
# Location_Jaipur               0
# Location_Kochi                0
# Location_Kolkata              0
# Location_Mumbai               0
# Location_Pune                 0
# Fuel_Type_Diesel              0
# Fuel_Type_LPG                 0
# Fuel_Type_Petrol              0
# Transmission_Manual           0
# Owner_Type_Fourth & Above     0
# Owner_Type_Second             0
# Owner_Type_Third              0
# dtype: int64

# %%
#filling missing values with mean and mode
tfe['Engine']=tfe['Engine'].fillna(tfe['Engine'].mean())
tfe['Power']=tfe['Power'].fillna(tfe['Power'].mean())
tfe['Mileage']=tfe['Mileage'].fillna(tfe['Mileage'].mean())
tfe['Seats']=tfe['Seats'].fillna(tfe['Seats'].mode()[0]) #mode(index) - filling with most common element
tfe
# Out:
#       Unnamed: 0  Year  Kilometers_Driven  Mileage  Engine      Power  Seats  \
# 0              0  2014              40929    32.26   998.0   58.20000    4.0
# 1              1  2013              54493    24.70   796.0   47.30000    5.0
# 2              2  2017              34000    13.68  2393.0  147.80000    7.0
# 3              3  2012             139000    23.59  1364.0  110.38042    5.0
# 4              4  2014              29000    18.50  1197.0   82.85000    5.0
# ...          ...   ...                ...      ...     ...        ...    ...
# 1229        1229  2011              89411    20.54  1598.0  103.60000    5.0
# 1230        1230  2015              59000    17.21  1197.0  103.60000    5.0
# 1231        1231  2012              28000    23.08  1461.0   63.10000    5.0
# 1232        1232  2013              52262    17.20  1197.0  103.60000    5.0
# 1233        1233  2014              72443    10.00  2148.0  170.00000    5.0
#
# ...

# %%
x1=tfe
x1
# Out:
#       Unnamed: 0  Year  Kilometers_Driven  Mileage  Engine      Power  Seats  \
# 0              0  2014              40929    32.26   998.0   58.20000    4.0
# 1              1  2013              54493    24.70   796.0   47.30000    5.0
# 2              2  2017              34000    13.68  2393.0  147.80000    7.0
# 3              3  2012             139000    23.59  1364.0  110.38042    5.0
# 4              4  2014              29000    18.50  1197.0   82.85000    5.0
# ...          ...   ...                ...      ...     ...        ...    ...
# 1229        1229  2011              89411    20.54  1598.0  103.60000    5.0
# 1230        1230  2015              59000    17.21  1197.0  103.60000    5.0
# 1231        1231  2012              28000    23.08  1461.0   63.10000    5.0
# 1232        1232  2013              52262    17.20  1197.0  103.60000    5.0
# 1233        1233  2014              72443    10.00  2148.0  170.00000    5.0
#
# ...

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x,y)
y_pred=reg.predict(x1)
y_pred
# Out:
# /home/harwick/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([ 3.10390538, -1.07897377, 16.31040133, ...,  0.25906902,
#         9.38206124, 21.58841907])
